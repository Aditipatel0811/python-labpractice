# %%
from tkinter import * 
base = Tk()  
base.geometry("550x550")  
base.title('Airline booking')

lbl_0 = Label(base, text="Airline booking")   
lbl_0.pack()  
  

lbl_1 =Label(base, text= "enter your name")  
lbl_1.pack()  
  
en_1 = Entry(base)  
en_1.pack() 
   
lbl_2 = Label(base, text="enter your registered mail")  
lbl_2.pack()  
  
en_2 = Entry(base)  
en_2.pack() 

lbl_3 = Label(base, text="enter your departure")  
lbl_3.pack() 
  
en_3 = Entry(base)  
en_3.pack() 

lbl_4= Label(base, text="enter your Arrival")  
lbl_4.pack()  
  
en_4 = Entry(base)  
en_4.pack() 
   
lbl_5 = Label(base, text="Gender")  
lbl_5.pack()   
     
vars = IntVar()  
   
Radiobutton(base, text="Male", padx= 5, variable= vars, value=1).pack()   
Radiobutton(base, text="Female", padx= 20, variable= vars, value=2).pack()  
  
  
lbl_6 = Label(base, text="enter your Age")  
lbl_6.pack() 
  
en_6 = Entry(base)  
en_6.pack() 

lbl_7=Label(base, text ="Country")  
lbl_7.pack() 
  
 
list_of_cntry=[ 'India' ,'Canada' , 'US' ,'Germany' ,'UK']  
    
cv = StringVar()  
drplist = OptionMenu(base, cv, *list_of_cntry)  
drplist.config(width=15)  
cv.set('Select your Country')  
drplist.pack()
    
Button(base, text='confirm' , width=20, bg="brown",fg='white').pack() 
  
base.mainloop()  

print("Airline booking form is created susccesfully..........")
# Out:
# Airline booking form is created susccesfully..........

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('airlinedataset.csv')
print(df)
# Out:
#      Passenger ID First Name  Last Name  Gender  Age         Nationality  \
# 0           10856     Edithe     Leggis  Female   62               Japan
# 1           43872     Elwood       Catt    Male   62           Nicaragua
# 2           42633      Darby    Felgate    Male   67              Russia
# 3           78493   Dominica       Pyle  Female   71               China
# 4           82072        Bay    Pencost    Male   21               China
# ..            ...        ...        ...     ...  ...                 ...
# 244         62388   Carolynn  Blakeslee  Female   72  Dominican Republic
# 245         16449       Clio   Rainford  Female   35           Indonesia
# 246         73644       Tann      Lever    Male   27             Armenia
# 247         10843     Devina  Lukehurst  Female   16                Peru
# 248         15164     Worden     Patkin    Male   72  Dominican Republic
#
#                         Airport Name Airport Country Code   Country Name  \
# 0                   Coldfoot Airport                   US  United States
# 1                  Kugluktuk Airport                   CA         Canada
# 2             Grenoble-Isère Airport                   FR         France
# 3          Ottawa / Gatineau Airport                   CA         Canada
# 4                    Gillespie Field                   US  United States
# ..                               ...                  ...            ...
# 244                     Wana Airport                   PK       Pakistan
# 245                 Nevatim Air Base                   IL         Israel
# 246          Abel Santamaria Airport                   CU           Cuba
# 247  Barcelona International Airport                   ES          Spain
# 248               Battambang Airport                   KH       Cambodia
#
#     Airport Continent     Continents Departure Date Arrival Airport  \
# 0                 NAM  North America      6/28/2022             CXF
# 1                 NAM  North America     12/26/2022             YCO
# 2                  EU         Europe      1/18/2022             GNB
# 3                 NAM  North America      9/16/2022             YND
# 4                 NAM  North America      2/25/2022             SEE
# ..                ...            ...            ...             ...
# 244                AS           Asia      6/25/2022             WAF
# 245                AS           Asia      6/20/2022             VTM
# 246               NAM  North America      10/8/2022             SNU
# 247                EU         Europe     10/12/2022             BCN
# 248                AS           Asia     12/16/2022             BBM
#
#              Pilot Name Flight Status
# 0         Edithe Leggis       On Time
# 1           Elwood Catt       On Time
# 2         Darby Felgate       On Time
# 3         Dominica Pyle       Delayed
# 4           Bay Pencost       On Time
# ..                  ...           ...
# 244  Carolynn Blakeslee     Cancelled
# 245       Clio Rainford       Delayed
# 246          Tann Lever     Cancelled
# 247    Devina Lukehurst       Delayed
# 248       Worden Patkin       On Time
#
# [249 rows x 15 columns]

# %%
df = pd.read_csv('airlinedataset.csv')

# %%
# %matplotlib inline

# %%
df2 = df.head(10)
plt.plot(df2["Airport Name"], df2["Flight Status"])
plt.xlabel('Airport Name')
plt.ylabel('Flight Status')
plt.title('Airline details', fontsize = 20)
plt.show()

# %%
plt.bar(df2["Airport Name"], df2["Flight Status"])
plt.xlabel('Airport Name')
plt.ylabel('Flight Status')
plt.title('Airline details', fontsize = 20)
plt.show()

# %%
plt.scatter(df2["Airport Name"], df2["Flight Status"])
plt.xlabel('Airport Name')
plt.ylabel('Flight Status')
plt.title('Airline details', fontsize = 20)
plt.show()

# %%
plt.title('Correlation')

x = df["Nationality"]
y = df["Age"]

plt.scatter(x,y)
 
plt.plot(np.unique(x),
         np.poly1d(np.polyfit(x, y, 1))
         (np.unique(x)), color='red')
 
# Labelling axes
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\aditi\OneDrive\Documents\HTML DUMP\labexe.ipynb Cell 8 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> y = df["Age"]
#       <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> plt.scatter(x,y)
#       <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> plt.plot(np.unique(x),
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>          np.poly1d(np.polyfit(x, y, 1))
#      <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>          (np.unique(x)), color='red')
#      <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> # Labelling axes
#      <a href='vscode-notebook-cell:/c%3A/Users/aditi/OneDrive/Documents/HTML%20DUMP/labexe.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> plt.xlabel('x axis')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\polynomial.py:630, in polyfit(x, y, deg, rcond, full, w, cov)
#     455 """
#     456 Least squares polynomial fit.
#     457
#    (...)
#     627
#     628 """
#     629 order = int(deg) + 1
# --> 630 x = NX.asarray(x) + 0.0
#     631 y = NX.asarray(y) + 0.0
#     633 # check arguments.
#
# TypeError: can only concatenate str (not "float") to str
